# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.sort_values("HP")
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.shape
# Out:
# (800, 13)

# %%
df.sort_values("Sp. Atk")
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 230  213                Shuckle      Bug    Rock    505   20      10      230
# 486  438                 Bonsly     Rock     NaN    290   50      80       95
# 381  349                 Feebas    Water     NaN    200   20      15       20
# 19    15  BeedrillMega Beedrill      Bug  Poison    495   65     150       40
# 614  554               Darumaka     Fire     NaN    315   70      90       45
# ..   ...                    ...      ...     ...    ...  ...     ...      ...
# 71    65  AlakazamMega Alakazam  Psychic     NaN    590   55      50       65
# 422  382    KyogrePrimal Kyogre    Water     NaN    770  100     150       90
# 426  384  RayquazaMega Rayquaza   Dragon  Flying    780  105     180      100
# 429  386     DeoxysAttack Forme  Psychic     NaN    600   50     180       20
# 164  150    MewtwoMega Mewtwo Y  Psychic     NaN    780  106     150       70
#
# ...

# %%
df[df["Type 1"]=="Flying"].sort_values("Sp. Atk")
# Out:
#        #                     Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 790  714                   Noibat  Flying  Dragon    245  40      30       35
# 791  715                  Noivern  Flying  Dragon    535  85      70       80
# 703  641    TornadusTherian Forme  Flying     NaN    580  79     100       80
# 702  641  TornadusIncarnate Forme  Flying     NaN    580  79     115       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 703      110       90    121           5       True
# 702      125       80    111           5       True

# %%
df[df["Type 2"] == "Psychic"]
# Out:
#        #                     Name    Type 1   Type 2  Total   HP  Attack  \
# 85    79                 Slowpoke     Water  Psychic    315   90      65
# 86    80                  Slowbro     Water  Psychic    490   95      75
# 87    80      SlowbroMega Slowbro     Water  Psychic    590   95      75
# 110  102                Exeggcute     Grass  Psychic    325   60      40
# 111  103                Exeggutor     Grass  Psychic    520   95      95
# 130  121                  Starmie     Water  Psychic    520   60      75
# 133  124                     Jynx       Ice  Psychic    455   65      50
# 214  199                 Slowking     Water  Psychic    490   95      75
# 218  203                Girafarig    Normal  Psychic    455   70      80
# 257  238                 Smoochum       Ice  Psychic    305   45      30
# 334  307                 Meditite  Fighting  Psychic    280   30      40
# 335  308                 Medicham  Fighting  Psychic    410   60      60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df["Speed"].value_counts()
# Out:
# Speed
# 50     46
# 60     44
# 70     37
# 65     36
# 30     35
#        ..
# 39      1
# 24      1
# 82      1
# 113     1
# 123     1
# Name: count, Length: 108, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df[df["Legendary"]])
# Out:
# 65

# %%
df.sort_values("Attack")
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 488  440                  Happiny   Normal       NaN    220  100       5
# 121  113                  Chansey   Normal       NaN    450  250       5
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# ..   ...                      ...      ...       ...    ...  ...     ...
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df["Name"]=="Jolteon"]
# Out:
#        #     Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 146  135  Jolteon  Electric    NaN    525  65      65       60      110
#
#      Sp. Def  Speed  Generation  Legendary
# 146       95    130           1      False

# %%
df_type = df[df["Type 1"] == "Ground"]

# %%
df_type_gen1 = df_type[df_type["Generation"] == 1]

# %%
df_type_gen1
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 32    27  Sandshrew  Ground    NaN    300   50      75       85       20
# 33    28  Sandslash  Ground    NaN    450   75     100      110       45
# 55    50    Diglett  Ground    NaN    265   10      55       25       35
# 56    51    Dugtrio  Ground    NaN    405   35      80       50       50
# 112  104     Cubone  Ground    NaN    320   50      50       95       40
# 113  105    Marowak  Ground    NaN    425   60      80      110       50
# 119  111    Rhyhorn  Ground   Rock    345   80      85       95       30
# 120  112     Rhydon  Ground   Rock    485  105     130      120       45
#
#      Sp. Def  Speed  Generation  Legendary
# 32        30     40           1      False
# 33        55     65           1      False
# 55        45     95           1      False
# 56        70    120           1      False
# 112       50     35           1      False
# 113       80     45           1      False
# ...

# %%
df_type_gen1_sorted = df_type_gen1.sort_values("Sp. Def")

# %%
df_type_gen1_sorted
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 32    27  Sandshrew  Ground    NaN    300   50      75       85       20
# 119  111    Rhyhorn  Ground   Rock    345   80      85       95       30
# 55    50    Diglett  Ground    NaN    265   10      55       25       35
# 120  112     Rhydon  Ground   Rock    485  105     130      120       45
# 112  104     Cubone  Ground    NaN    320   50      50       95       40
# 33    28  Sandslash  Ground    NaN    450   75     100      110       45
# 56    51    Dugtrio  Ground    NaN    405   35      80       50       50
# 113  105    Marowak  Ground    NaN    425   60      80      110       50
#
#      Sp. Def  Speed  Generation  Legendary
# 32        30     40           1      False
# 119       30     25           1      False
# 55        45     95           1      False
# 120       45     40           1      False
# 112       50     35           1      False
# 33        55     65           1      False
# ...

# %%
sns.boxplot(x ="Generation", y = "HP", data=df)
# Out:
# <Axes: xlabel='Generation', ylabel='HP'>

# %%
quantile_97 = np.percentile(df["HP"],97)
quantile_97
# Out:
# 120.08999999999992

# %%
hp_outliers_df = df[df["HP"] > quantile_97]

# %%
hp_outliers_id = hp_outliers_df.index.tolist()

# %%
hp_outliers_id
# Out:
# [45,
#  121,
#  142,
#  145,
#  155,
#  185,
#  217,
#  261,
#  313,
#  321,
#  350,
#  351,
#  473,
#  495,
#  544,
#  545,
#  655,
#  710,
#  711,
#  712,
#  741,
#  769,
#  792,
#  793]

# %%
df_hp_no_outliers = df.drop(index = hp_outliers_id)

# %%
df_hp_no_outliers
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
sns.boxplot(x = 'Generation', y = 'HP', data = df_hp_no_outliers)
# Out:
# <Axes: xlabel='Generation', ylabel='HP'>

# %%
type_weaknesses = {
    'Normal': ['Fighting'],
    'Fire': ['Water', 'Ground', 'Rock'],
    'Water': ['Electric', 'Grass'],
    'Electric': ['Ground'],
    'Grass': ['Fire', 'Ice', 'Poison', 'Flying', 'Bug'],
    'Ice': ['Fire', 'Fighting', 'Rock', 'Steel'],
    'Fighting': ['Flying', 'Psychic', 'Fairy'],
    'Poison': ['Ground', 'Psychic'],
    'Ground': ['Water', 'Grass', 'Ice'],
    'Flying': ['Electric', 'Ice', 'Rock'],
    'Psychic': ['Bug', 'Ghost', 'Dark'],
    'Bug': ['Fire', 'Flying', 'Rock'],
    'Rock': ['Water', 'Grass', 'Fighting', 'Ground', 'Steel'],
    'Ghost': ['Ghost', 'Dark'],
    'Dragon': ['Ice', 'Dragon', 'Fairy'],
    'Dark': ['Fighting', 'Bug', 'Fairy'],
    'Steel': ['Fire', 'Fighting', 'Ground'],
    'Fairy': ['Poison', 'Steel']
}

# %%
def get_weaknesses(type1, type2=None):
    # Get weaknesses for Type 1
    weaknesses = set(type_weaknesses.get(type1, []))
    
    # If there's a Type 2, get its weaknesses and merge them
    if type2:
        weaknesses.update(type_weaknesses.get(type2, []))
    
    return list(weaknesses)

# %%
df['Weakness'] = df.apply(lambda row: get_weaknesses(row['Type 1'], row['Type 2']), axis=1)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
#
#                                             Weakness
# 0  [Flying, Poison, Fire, Ice, Psychic, Bug, Ground]
# 1  [Flying, Poison, Fire, Ice, Psychic, Bug, Ground]
# 2  [Flying, Poison, Fire, Ice, Psychic, Bug, Ground]
# ...

# %%
#Code Pokemon counter
def Counter(Pokemon):
    pokemon_weakness = df.loc[df['Name'] == Pokemon ["Weakness"]]

# %%
csv_path = input("Enter the path to the Pokedex CSV file: ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 input()
#
# TypeError: 'str' object is not callable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
#  13  Weakness    800 non-null    object
# dtypes: bool(1), int64(9), object(4)
# memory usage: 82.2+ KB
